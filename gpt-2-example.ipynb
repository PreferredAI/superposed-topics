# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pickle
import numpy as np
import pandas as pd
from algo.topics import single_count_setup
from algo.utils import index_vocab
from gpt2.shortlist import shortlist_decode

# %%
'''
Code to download GPT-2
'''
# from gpt2.utils import download_gpt2_files
# for size in ["124M", "355M", "774M", "1558M"]:
#     download_gpt2_files(size, "./models")

# %%
model_dir = "./models"
model_size = "1558M"

graph_dir = "/data/jiapeng/wiki/final_2/10"
single_count_path = '/data/jiapeng/wiki/final_2/10_single.pkl'
hist_file = "/data/jiapeng/wiki/histogram.csv"
wiki_vocab = pickle.load(open("/data/jiapeng/wiki/vocab.pkl", 'rb'))
min_freq = 100
window_size = 10

wiki_vocab2id, wiki_id2vocab = index_vocab(list(wiki_vocab.keys()))
shortlist_decoder = shortlist_decode(wiki_vocab2id, model_size, 
                                          model_dir, extra_vocab=[])

wiki_num_windows, wiki_single_prob = single_count_setup(hist_file, 
                                                        single_count_path,
                                                        window_size, min_freq)

# %%
'''
We obtain the logit distribution by activating a neuron singly
In this example, we do it for just one neuron on Hi-C (mode I)
'''

from gpt2.model import gpt2_mod_i
from gpt2.utils import load_encoder_hparams_and_params
from gpt2.shortlist import shortlist_solve, multi_helper

encoder, hparams, params = load_encoder_hparams_and_params(model_size, model_dir)

layer_id = 26
neuron_id = 5201

MLP = params['blocks'][0]['mlp']['c_proj']['w'].shape[0]
batches = np.eye(MLP, MLP)

test = np.array(gpt2_mod_i(batches[neuron_id], wte=params['wte'],blocks=params['blocks'],
                  ln_f=params['ln_f'],n_head=hparams["n_head"],inject=layer_id))

print(test.shape)
# Out:
# (1, 50257)

# %%
'''
Shortlisting step to get the top and lowest activations
'''

arg_matrix = arg_matrix = np.argsort(test[0])
tau = 900
neg = {shortlist_decoder[k] for k in arg_matrix[:tau] 
           if k in shortlist_decoder}
pos = {shortlist_decoder[k] for k in arg_matrix[-tau:] 
       if k in shortlist_decoder}

# %%
'''
Projecting to Wikipedia Graphs, followed by exact solving using MMEKC
The topics from neg pool produced is as seen from the appendix
'''

from algo.extract import MMEKC
from algo.topics import get_topics

neg_topics = get_topics(neg, graph_dir, wiki_num_windows, 
                                      min_freq, wiki_single_prob)

results, isets = MMEKC(neg_topics, thresholds=(0.1,1), size_limits=(10,24), time_limit_s=120)
for result, iset in zip(results,isets):
    topic_ids, score = result
    print(" ".join([wiki_id2vocab[x] for x in iset]), f"({len(iset)})")
    print(" ".join([wiki_id2vocab[x] for x in topic_ids]), score)
    print()
# Out:
# lutheran oslo danish stockholm viking norse norwegian sweden swedish helsinki copenhagen scandinavian (12)
# copenhagen swedish oslo norwegian helsinki stockholm viking danish scandinavian sweden 0.23735375280168527
#
# archbishop pope worcester premiership earthquake leicester norwich cathedral pilgrim bishop canterbury (11)
# archbishop bishop pope earthquake pilgrim canterbury norwich worcester cathedral leicester 0.09824852693207832
#
# salvation souls doctrine orthodox resurrection mercy sins conversion sacrament repentance (10)
# salvation souls doctrine repentance sins mercy conversion sacrament resurrection orthodox 0.17949054874666126

# %%
'''
We repeat the process for pos pool
Again, these topics are as seen from the appendix
'''

pos_topics = get_topics(pos, graph_dir, wiki_num_windows, 
                                      min_freq, wiki_single_prob)

results, isets = MMEKC(pos_topics, thresholds=(0.1,1), size_limits=(10,24), time_limit_s=120)
for result, iset in zip(results,isets):
    topic_ids, score = result
    print(" ".join([wiki_id2vocab[x] for x in iset]), f"({len(iset)})")
    print(" ".join([wiki_id2vocab[x] for x in topic_ids]), score)
    print()
# Out:
# wednesday saturday tuesday monday month morning february good daily day night thursday sunday tonight friday (15)
# sunday morning monday wednesday night friday saturday thursday day tuesday 0.33148646093748896
#
# correctly crowd drive got decided pass flip bat throw throws tie beat tossed bet toss (15)
# bat throws drive tossed got crowd pass tie toss throw 0.10929527706674895
#
# modules boot array client command install installed tracking control smart function functions module (13)
# module modules client smart control functions install tracking installed array 0.11403861688252051
#
# don let guys exactly going tell feel ought understand need answer getting folks better come pretty like certainly people sort feeling fun little know (24)
# let pretty tell going like fun don feel know guys 0.17885697409360674

# %%
'''
We compare to random, to ensure that what we got was meaningful
While a single example does not reflect the entire random distribution
We can observe that very good topics can be found
Setting a very large $tau$ increases the advantage of the random baseline
'''
import random
idx = list(range(50257))
random.shuffle(idx)
rand_pool = {shortlist_decoder[k] for k in idx[-tau:] if k in shortlist_decoder}
rand_topics = get_topics(rand_pool, graph_dir, wiki_num_windows, min_freq, wiki_single_prob)
results, isets = MMEKC(rand_topics, thresholds=(0.1,1), size_limits=(10,24), time_limit_s=120)
for result, iset in zip(results,isets):
    topic_ids, score = result
    print(" ".join([wiki_id2vocab[x] for x in iset]), f"({len(iset)})")
    print(" ".join([wiki_id2vocab[x] for x in topic_ids]), score)
    print()
# Out:
# diverse diversity reef dolphins prey eggs shrimp food rays fishes (10)
# diversity fishes eggs food reef rays dolphins shrimp diverse prey 0.08609391579800717
#
# miz tara hogan team lost win html url demolition successfully hardy tag (12)
# hogan win miz lost tag team demolition tara hardy successfully 0.03405867872378255
#
# target undergoing fatigue administered stem respond aids protocols proven complications medical node physicians healthy treatments chemotherapy (16)
# undergoing administered complications aids medical healthy treatments physicians chemotherapy respond 0.12153163523996449
#
# fusion tap artery rehabilitation activation wound fiber medial ankle function spinal (11)
# medial fusion function fiber rehabilitation ankle activation spinal wound artery -0.011409897917609442
#
# fuzzy county dots crush dutch narrower alert shirt fruits orange (10)
# shirt narrower county fruits dutch alert fuzzy crush orange dots -0.18895207988312487

# %%
"""
The following code does the above on a larger-scale
"""
from gpt2.model import gpt2_crawl

model_dir = "./models"
model_size = "124M"
layer_outputs = gpt2_crawl(model_dir, model_size, 3, layers=[0,1], batch_size=32)
print(len(layer_outputs), type(layer_outputs))
print(layer_outputs[0].shape)
# Out:
# 100%|██████████| 24/24 [00:25<00:00,  1.07s/it]
# 100%|██████████| 24/24 [00:23<00:00,  1.02it/s]
# 2 <class 'dict'>
# (768, 50257)

# %%
'''
shortlist_solve uses Pools to call multiple MMEKC
optional to pass in names
'''
from gpt2.shortlist import shortlist_solve
test = layer_outputs[0][0:8,:]
shortlist_solve(test, dest_dir='./outputs', tau=900, thresholds=(0.1,1), size_limits=(10,24),
               graph_dir=graph_dir, num_windows=wiki_num_windows, 
                min_freq=min_freq, single_prob=wiki_single_prob, 
                shortlist_decoder=shortlist_decoder, verbose=1)
# Out:
# processing: 8
# STOP : ./outputs/1 : 15s
# STOP : ./outputs/2 : 16s
# STOP : ./outputs/0 : 25s
# STOP : ./outputs/3 : 28s
# STOP : ./outputs/4 : 20s
# STOP : ./outputs/7 : 10s
# STOP : ./outputs/5 : 23s
# STOP : ./outputs/6 : 15s

# %%
from algo.utils import read_topics, read_isets
for i in range(8):
    print('Example', i)
    pos_isets = read_isets(f"./outputs/{i}_pos_isets.csv", wiki_id2vocab)
    neg_isets = read_isets(f"./outputs/{i}_neg_isets.csv", wiki_id2vocab)
    pos_topics = read_topics(f"./outputs/{i}_pos_topics.csv", wiki_id2vocab)
    neg_topics = read_topics(f"./outputs/{i}_neg_topics.csv", wiki_id2vocab)
    print(f'NEG ({len(neg_isets)})')
    if len(neg_isets) == 0: print(' EMPTY')
    for iset, topics in zip(neg_isets,neg_topics):
        print(" ".join(iset), f"({len(iset)})")
        print(' ', " ".join(topics[0]), topics[1])
        print()
    print(f'POS ({len(pos_isets)})')
    if len(pos_isets) == 0: print(' EMPTY')
    for iset, topics in zip(pos_isets,pos_topics):
        print(" ".join(iset), f"({len(iset)})")
        print(' ', " ".join(topics[0]), topics[1])
        print()
    print('\n','='*20)
# Out:
# Example 0
# NEG (0)
#  EMPTY
# POS (21)
# high children science lunch sports girls secondary curriculum closed prep grade college program education math law school (17)
#   math high girls secondary curriculum grade college school education prep 0.1940944472231845
#
# items cut pair price kick sharp thread hand tool piece running tail scissors (13)
#   thread sharp tool tail hand piece running cut scissors pair 0.0893952992701257
#
# childhood mother girl family daughter young sex sexual laptop inquiry life birth child (13)
#   daughter young sex child mother childhood girl life family birth 0.1536742521138479
#
# talent miss reality charm truth love art earth natural nature products shop perfect innocence sleeping beauty (16)
#   miss charm perfect reality nature love innocence beauty truth talent 0.1281501138763905
#
# sorted poll house ign built stock table list sale listed (10)
#   list listed poll stock table ign built sorted sale house -0.0084403733247289
#
# drive code adventure file default land inside skip slide zip (10)
#   drive default inside code land zip adventure slide file skip -0.0057357563039224
#
# coupon special seat state government prime commission cast sitting vote slim bid run snap election (15)
#   run election state seat government special sitting prime vote snap 0.0972428699957252
#
# eye accidental accidentally accidents fault collision airplane incident flaw flight emergency road car happen left traffic tragedy error investigation safety mining accident (22)
#   accident accidental accidents investigation car traffic safety emergency collision incident 0.1601864378921237
#
# temperature low hot spring spy sensitive dark air vacuum neutral summer case fresh war warm trap cold (17)
#   fresh spring warm hot summer sensitive cold temperature low air 0.1386429155731823
#
# bonus self decision inc return reverse value int entry round random def (12)
#   self round def value decision inc int return random reverse 0.0533207852376923
#
# funny opinion loop critical spin box test false zero negative review net root episode biased bias fun positive (18)
#   opinion review positive negative biased critical zero bias test false 0.1343026097189491
#
# hole red magic seeds man green matter shorts tie tip rot black (12)
#   magic black red seeds man tip tie green hole matter 0.0513601281864891
#
# cache memory hardware clock idle core reset mode computer logic bits embedded configured software data micro slot pin dual switches timing configuration internal cpu (24)
#   cpu logic data hardware embedded bits computer cache memory software 0.2183182892898112
#
# ignition gear cam manual wheels search rear screw optional power mach option installed options design room available removable fire type compact choices seconds engine (24)
#   option optional options gear engine wheels ignition rear available manual 0.2006082132445831
#
# missed opener backup button ball right pull torn photo pick picking picks pinch thumb (14)
#   missed opener torn backup thumb pick right button picks ball 0.0690247183728066
#
# location lock mobile pocket log satellite technology position clocks navigation use fix electronics compass camera cameras information phone radio smart system gps (22)
#   navigation electronics gps satellite phone smart camera cameras technology mobile 0.1866559260856959
#
# play team chosen host select selecting selection pro competition bench best randomly selected (13)
#   play select selected selecting selection team randomly chosen host competition 0.1412987694186636
#
# mission trip motion dust probe night half tilt sun destination rotation light moon (13)
#   light rotation dust motion night moon sun probe tilt half 0.0823545988721021
#
# policy fair secrets coal illegal economic business fishing commercial foreign free trade (12)
#   fishing business free foreign fair economic illegal commercial policy trade 0.0849720939835157
#
# twist steel ground deep gun basic depth rotating dig drill (10)
#   ground basic rotating steel dig depth gun deep drill twist 0.0488170653783942
#
# loaded locked locks turning door action key cable theft quick angle switch escape safe locking (15)
#   loaded switch locking turning key locked escape door safe locks 0.1125489442319116
#
#
#  ====================
# Example 1
# NEG (0)
#  EMPTY
# POS (10)
# islam islamic arab arabic chinese christian women attacks muslims egyptian syria syrian muslim (13)
#   arab islam arabic islamic egyptian christian syria syrian muslim muslims 0.2405238664834182
#
# approximately south west western lying sea east eastern near flat north roughly lie lies (14)
#   roughly lies north west western lying eastern east south approximately 0.210271701077656
#
# children creatures family male years dead age things individuals people person total living (13)
#   male age living years children family total individuals person people 0.123784425853355
#
# web books twitter facebook accounts earth images com computer video devices phone phones photos internet billion google (17)
#   twitter phone photos facebook phones google internet web com devices 0.1956563563905185
#
# long cut pairs stories story sharp thick thin length best short (11)
#   sharp stories thick short story length cut long thin pairs 0.0998833711765904
#
# live trump abc according fbi reuters told fox cbs said cnn (11)
#   fox trump reuters according said told abc cbs cnn fbi 0.1094018113585374
#
# wednesday lost hook face season second seconds away straight match matches super pick minute reach round (16)
#   straight round away match second matches minute lost seconds season 0.1430637539621528
#
# solid chemical police coal cold filled natural air energy discovered water gas (12)
#   filled natural energy solid chemical water cold gas coal air 0.1102778120965298
#
# know think tell honestly understand let maybe thing look love hear like happen lot mean pretty crazy funny come try knows kind weird don (24)
#   funny kind weird pretty crazy thing think maybe don know 0.2148499998847662
#
# chest witnesses man killed fire ball enemy instantly minutes shot (10)
# son mother family father steven daughter nick personal sister celebrity big friend brother (13)
#   son daughter sister mother family father steven brother friend nick 0.1624522149209498
#
# corporations gang technology chinese experts credit criminal fake break secure fbi data find network networks hacker employees card cards russian systems hackers (22)
#   secure data network hackers networks card systems cards credit technology 0.1264219170791451
#
# talk reality special popular host feature pal series cable canadian footage american personality voice anime digital celebrities television (18)
#   talk television series reality anime voice celebrities popular host personality 0.1277362764166845
#
# japanese armed army terror terrorism overseas start aerial battle forces enemy war (12)
#   aerial battle enemy army war terror japanese forces armed overseas 0.1206026638482395
#
# corporation exchange holding options corporate manufactured stocks firm share shares common companies company float employee swap stock (17)
#   corporate corporation company stock firm share companies holding stocks shares 0.1838068945043266
#
# long species white man steel dark stories deep tower pink tall (11)
#   white stories pink tall man tower steel deep long dark 0.0885822319342239
#
# trick loaded open space port crew double main fire floating capable carry equipment deck (14)
#   loaded capable carry space crew equipment floating deck port fire 0.0931419055792096
#
# try look lot honest hide feel wrong kind know come things people happen let walk like mind bit cops don (20)
#   lot let bit things look like happen don feel know 0.180867287475758
#
# fuse blood chemical jail dna specific possess type types human lab complex inside contents cellphone cell (16)
#   complex specific type cell types dna possess chemical human blood 0.106493980435945
#
# old names combination use commonly language english root literally word (10)
#   use english combination names commonly literally word root old language 0.0934711194257876
#
#
#  ====================
# Example 4
# NEG (0)
#  EMPTY
# POS (16)
# bloody wednesday week saturday tuesday monday month morning hours draw starting march day days night sunday round held friday place thursday (21)
#   sunday monday morning night saturday tuesday wednesday week friday thursday 0.3340696821745444
#
# living old spent spread family remained seven age ages ago nearly later period died years (15)
#   spread living seven age ago years ages died family old 0.1200843770773029
#
# played playing sea feet ground mean rise tide water level (10)
#   ground played rise sea playing mean tide water level feet 0.0852993226007169
#
# weather wind spring winter drop dry cuts air conditions end summer rolled fresh war cold (15)
#   fresh conditions spring summer wind dry weather cold winter air 0.1542301077786773
#
# exact soon weeks child children gave born months boy mother date baby parents sleep life control birth (17)
#   child gave mother children parents baby life boy born birth 0.1683535650132991
#
# taken takes taking home doesn don workers services needed need sick animal animals didn health care (16)
#   care workers services sick need needed didn don doesn health 0.0879925848615744
#
# army movements movement broke government service law laws russian military civil (11)
#   laws government military army russian civil law movement movements service 0.0751782598262827
#
# sold israel bought owned built settled buy people town land (10)
#   sold buy israel owned town land bought built settled people 0.0645820590803613
#
# real money dollars job women working cut goods paid economic economy agreed strike labor labour pay demand food supply better trade wages (22)
#   labour food demand trade wages economic economy supply goods labor 0.1415733454467683
#
# live sound records christmas released music band performed track recorded (10)
#   sound music released band performed track christmas live recorded records 0.1440349984688843
#
# offered approved joined worth good fell struck sign signed announced deal (11)
#   good fell offered struck announced sign worth approved signed deal 0.0468438324150529
#
# troops police arrived ordered fighting necessary ships forces men planes force (11)
#   troops fighting arrived planes force police forces ships men ordered 0.1117287821607386
#
# existed exists actually things simply merely cease ceased continue exist (10)
#   cease ceased simply actually exist existed merely exists things continue 0.0535401292785919
#
# lot turn terrible getting makes feel feeling wrong got awful bad thing condition hell worse (15)
#   terrible worse got awful wrong lot bad feel feeling thing 0.1928308925701478
#
# loaded arrive bound seized broken fire fired returned laid delivered shore ship (12)
#   fired loaded seized returned shore ship broken laid fire bound 0.0694089768938816
#
# ready way sort look looking looked moment saying ass absolutely going felt kind find come thought happened hard wanted said sure (21)
#   sure saying wanted felt kind going absolutely said look sort 0.136683757644903
#
#
#  ====================
# Example 5
# NEG (1)
# winter weather action epa ice temperature maps crop ocean climate (10)
#   epa ice climate weather maps action crop winter temperature ocean 0.0337027951793703
#
# POS (15)
# living old family present years young death individuals size race heart line age (13)
#   young age living years death family size present individuals old 0.1459331029758631
#
# countless potentially dozens worth thousand thousands people pieces billions millions hundreds (11)
#   potentially millions pieces billions worth hundreds dozens thousand thousands people 0.1306283019107572
#
# approximately long open array doors outer separated dark upper deep thick base sides tip roughly range wide (17)
#   thick base tip upper outer deep sides long dark wide 0.1936465478983029
#
# mission chief army hot wing attack unit defence flying force forces quality training control military systems air (17)
#   flying attack training military army defence force forces unit air 0.1551016383568297
#
# know think want forget tell understand feel let believe remember maybe thing saying look aren need shouldn things everybody said stop hear like don (24)
#   saying want shouldn thing things think maybe don feel know 0.2356708637834249
#
# talking mobile police speaking telling mysterious available urgent calling calls emergency information message voice touch heard number numbers smart friend phone (21)
#   mysterious talking telling voice calling calls phone message mobile heard 0.1285925383844673
#
# reality weapon soul spirit spiritual absolute fantastic self unity universe fight fighting super supreme survival challenge ultimate (17)
#   soul self spirit ultimate spiritual reality unity universe supreme absolute 0.1396857341346815
#
# example sounds specific words repeating sense names use common language mean means simply singular object word (16)
#   singular specific sense means mean word object words language example 0.1335794327750562
#
# team extraordinary brilliant repeat easy impossible incredible perfect amazing times single feat (12)
#   easy perfect extraordinary single feat amazing times brilliant impossible incredible 0.0665173581093112
#
# highly distant portion face clear clearly remain star easily parts barely inside wall obvious invisible apparent hidden visible (18)
#   clear visible apparent inside hidden easily wall obvious invisible clearly 0.0963365464343601
#
# exact exactly making dangerous easier problem problems particularly properly incredibly prove complex hard obviously challenging difficult (16)
#   problems hard challenging difficult making particularly dangerous incredibly prove problem 0.0967902805868075
#
# ways distinct exist choose type types multiple kind kinds groups concepts belong levels totally different (15)
#   type types concepts ways exist kinds levels multiple different distinct 0.1102900184885599
#
# experts global secure act government foreign energy legitimate intelligence vital social security (12)
#   government global foreign energy secure act intelligence vital security experts 0.0755482541057104
#
# ready way couldn sort truly lot absolutely wonderful actually going good dead come needs definitely proud thought perfectly happen certainly wanted sure (22)
#   sure wanted lot definitely going absolutely proud wonderful happen couldn 0.1482407537947731
#
# real true brand secret unified unique separate individual person hide identity (11)
#   true individual separate secret brand unique identity real person hide 0.0583799481250183
#
#
#  ====================
# Example 6
# NEG (0)
#  EMPTY
# POS (12)
# apple sony game games facebook windows mac com inc nintendo amazon android microsoft free switch iphone app ios (18)
#   app apple switch android iphone microsoft windows mac ios nintendo 0.3284870914446846
#
# tuesday jan jun feb aug sept col mar dec marvel comics batman thursday superman vladimir nov oct (17)
#   jan aug oct dec comics nov superman sept marvel feb 0.3253395955791606
#
# santa los louis luis texas california las carlos international antonio san (11)
#   los carlos las santa international california texas luis antonio san 0.1539986734364942
#
# red monday dragon dark green peter metro sky light blue (10)
#   metro red dragon light sky monday peter dark green blue 0.0867850566964411
#
# southern west western east eastern carolina north central wall south (10)
#   southern north west western central eastern east south wall carolina 0.1778386734980351
#
# isis israel trump turkey christian asia jordan bureau obama russia syrian iran syria (13)
#   obama israel trump russia jordan syria syrian iran turkey isis 0.1791488356366001
#
# bob jack hollywood ted christmas donald abc orlando magic florida hall victor ben michael mike walt (16)
#   magic michael bob hollywood jack ben christmas mike walt ted 0.1065871690029398
#
# april wednesday saturday jason jonathan thanksgiving july june february good august september march edition night halloween sunday super ross november october friday (22)
#   sunday november october night saturday wednesday thanksgiving friday halloween september 0.1802667993408399
#
# evan sam charlie son mitch secret father adam theresa richard amy henry jared (13)
#   son sam henry amy father secret adam richard jared charlie 0.1259574381226134
#
# hillary sanders wisconsin mrs secretary fbi president sen republican republicans bush barack indiana democratic democrats vice bill warren washington clinton (20)
#   clinton president democratic democrats sen vice republican republicans secretary bush 0.205747258617127
#
# true love jesus christopher john spirit daniel earth matthew paul thomas timothy andrew bible hell christ (16)
#   matthew paul jesus john christ andrew bible daniel timothy thomas 0.1789345551059598
#
# chicago boston aaron houston seattle cleveland atlanta dallas buffalo nba detroit minnesota milwaukee (13)
#   seattle chicago dallas houston milwaukee boston cleveland detroit atlanta buffalo 0.186107361331441
#
#
#  ====================
# Example 7
# NEG (1)
# activation module radiation flow temperature gradient capacitor requires data pixel fuel parameters sensor (13)
#   module parameters radiation gradient requires sensor data flow activation temperature 0.1240851796815958
#
# POS (4)
# white asian african native indian percent america american americans black hispanic (11)
#   black americans indian white hispanic african percent asian american native 0.2561829664011844
#
# approximately south area truth southern west western lying east eastern near north northern lie central lies (16)
#   lies southern north west western eastern northern east south approximately 0.2382644738960688
#
# wednesday week saturday tuesday monday christmas thanksgiving david day dead halloween thursday sunday friday night (15)
#   sunday monday wednesday thanksgiving week friday saturday thursday night tuesday 0.3216853874181066
#
# miss isn lot honest honestly love good wrong know thing things mean people let like obviously said don (18)
#   good honest honestly lot said isn don thing things know 0.182915852666212
#
#
#  ====================

# %%
'''
counting activations in the model for ZSTM

use extra_vocab to narrow the vocabulary further:
    shortlist_decoder = shortlist_decode(wiki_vocab2id, model_size, 
                                              model_dir, extra_vocab=[])

NPMI values of other corpus might not guarantee a score that correlates with human judgment
In most cases, using a subset of common vocabulary would work for estimation
'''
from gpt2.model import gpt2_get_votes

corpus = ['The flying fox jumps over the lazy dog',
         'Buffalo buffalo Buffalo buffalo buffalo buffalo Buffalo buffalo',
         'Pack my box with five dozen liquor jugs']

top_activated = gpt2_get_votes(model_dir, model_size, corpus, votes=5)
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  4